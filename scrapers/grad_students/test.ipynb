# %%
from yale_directory_scraper import Directory

# %%
dir = Directory('/Users/leonlufkin/Documents/GitHub/ydn-data/projects_2019/yale-most-popular-courses/scripts/chromedriver')

# %%
dir.search_directory('GS', 'alec')
dir.max_reached()
# Out:
# False

# %%
dir.soup
# Out:
# <!--[if lt IE 9]>
#       <div class="nogo">
#         The browser you are using is not supported. Please upgrade to the latest.
#       </div>
#     <![endif]-->
# <noscript>
# <div class="nogo">
#         JavaScript must be enabled in order to use Yale Directory.
#         It seems JavaScript is either disabled or not supported by your browser.
#         Please enable JavaScript by changing your browser options.
#     </div>
# </noscript>
# <div class="body_wrapper" style="display: block;">
# <!-- Header -->
# <header class="header js-toggle js-bound" id="header">
# <!-- Header Row -->
# <div class="header_row">
# <!-- Header Cell -->
# <div class="header_cell">
# <!-- Site Logo -->
# <a class="logo_main icon_only" href="https://www.yale.edu/" itemscope="" itemtype="http://schema.org/CollegeOrUniversity">
# <h1 class="offscreen" itemprop="name">Yale University</h1>
# <img alt="" class="print" src="https://www.yale.edu/sites/all/themes/yale_blue/images/logo-print.png"/>
# </a>
# ...

# %% [markdown]
# #### selenium

# %%
from selenium import webdriver
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('/Users/leonlufkin/Documents/GitHub/ydn-data/projects_2019/yale-most-popular-courses/scripts/chromedriver')
driver.get('https://directory.yale.edu/advanced')
# Out:
# /var/folders/gq/3xlhh9496_j9xpjb7tkbqh280000gn/T/ipykernel_26571/57328888.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/leonlufkin/Documents/GitHub/ydn-data/projects_2019/yale-most-popular-courses/scripts/chromedriver')

# %%
driver.get("https://directory.yale.edu/?queryType=field&firstname=alec&school=GS")
html_source_code = driver.execute_script("return document.body.innerHTML;")
soup = BeautifulSoup(html_source_code, 'html.parser')

# %%
s = soup.find_all("div", {"class": "directory_results_list"})[3]

# %%
[e.text for e in soup.find_all("div", {"class": "directory_results_list"})[3].select("a") if "@" in e.text]
# Out:
# ['alec.barrett@yale.edu',
#  'alec.eickbusch@yale.edu',
#  'alec.hegg@yale.edu',
#  'alec.sheffield@yale.edu',
#  'alec.walker@yale.edu',
#  'alec.wood@yale.edu',
#  'aleca.borsuk@yale.edu']

# %% [markdown]
# #### requests + cookies

# %%
import json
import requests
from bs4 import BeautifulSoup

# %%
def cookie_values_str(cookie: dict):
    return {key: str(value) for key, value in cookie.items()}

# %%
with open('ljl64_cookies.json') as f:
    cookies = json.load(f)

# %%
session = requests.Session()
#for cookie in cookies:
#    c = {key: str(value) for key, value in cookie.items()}
#    session.post('https://directory.yale.edu', cookies=c)

# %%
r = session.get('https://directory.yale.edu/?queryType=field&firstname=ale&school=GS', cookies=cookie_values_str(cookies[13]))
soup = BeautifulSoup(r.text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="boxshadow no-touch" lang="en">
# <head>
# <title>Directories | Yale University</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="no-cache, max-age=0, must-revalidate, no-store" http-equiv="Cache-Control"/>
# <meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/>
# <meta content="authenticity_token" name="csrf-param"/>
# <meta content="PnjbETpbuzHaOCeVkc2vf3cuw4DZbNar6hYunI0DtzDpUGMIUyBpUbA98jlh+aeKOuPIj0Y2TwxIEZCKDvh3Sg==" name="csrf-token"/>
# <link href="/assets/favicons/apple-touch-icon-57x57-4f74111e11be63e29f7a153557160d08d969547285b8abed2d65a6d0eb33965a.png" rel="apple-touch-icon" sizes="57x57" type="image/png"/>
# <link href="/assets/favicons/apple-touch-icon-60x60-58fcc62c3e3f94273a6a1f495493047a9cd7a7839197ccb1d97af2d8c9f66ff7.png" rel="apple-touch-icon" sizes="60x60" type="image/png"/>
# ...
